# %% [markdown]
# # Book Recommendation System Using Collaborative Filtering

# %% [markdown]
# ## Introduction
# This notebook demonstrates the development of a book recommendation system using **Collaborative Filtering**.
# The recommendation system is built using the **K-Nearest Neighbors (KNN)** algorithm to find books that are similar based on user ratings.
#
# Collaborative filtering works by identifying users with similar preferences and recommending books that similar users have enjoyed.

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Downloading The Datasets

# %%
import gdown
import os

# Function to download a file from Google Drive if it doesn't exist
def download_file(file_id, output):
    # Create the /data/ directory if it doesn't exist
    if not os.path.exists('data'):
        os.makedirs('data')

    # Full path to the file in /data/
    output_path = os.path.join('data', output)

    # Check if the file already exists
    if not os.path.exists(output_path):
        url = f"https://drive.google.com/uc?id={file_id}"
        gdown.download(url, output_path, quiet=False)
        print(f"{output} downloaded.")
    else:
        print(f"{output} already exists.")

# File IDs from Google Drive
books_file = '1U4kz_Y4A9fsnXPleHV_wYJ_yB4XxsJXs'
ratings_file = '1hMgOVMci3iaGLRrUKI-PRMBinPpQIXcP'
users_file = '195Mgo4sKzpJ9vfYqiVg7d_NL4vX4Iexj'

# Download files if they do not already exist in /data/
download_file(books_file, "Books.csv")
download_file(ratings_file, "Ratings.csv")
download_file(users_file, "Users.csv")
# Out:
# Books.csv already exists.
# Ratings.csv already exists.
# Users.csv already exists.

# %% [markdown]
# ### Data Preprocessing

# %%
books = pd.read_csv('data/Books.csv', low_memory=False)

# %%
books.sample(5)
# Out:
#               ISBN                                         Book-Title  \
# 259793  0312254210                                   Stein on Writing
# 119259  0061009571                                The Wilderness Road
# 198312  0866254064       Frontiersmen (Wild West in American History)
# 115808  0395186498  Curious George Takes a Job (Sandpiper Houghton...
# 246005  0404077749  Aucassin and Nicolette, and Other Mediaeval Ro...
#
#            Book-Author Year-Of-Publication  \
# 259793       Sol Stein                2000
# 119259  James Reasoner                1996
# 198312    Gail Stewart                1990
# 115808       H. A. Rey                1974
# 246005    Eugene Mason                1972
#
#                                  Publisher  \
# 259793                  St. Martin's Press
# 119259  Harper Mass Market Paperbacks (Mm)
# 198312                    Rourke Pub Group
# 115808                    Houghton Mifflin
# 246005                              Ams Pr
#
#                                               Image-URL-S  \
# 259793  http://images.amazon.com/images/P/0312254210.0...
# 119259  http://images.amazon.com/images/P/0061009571.0...
# 198312  http://images.amazon.com/images/P/0866254064.0...
# 115808  http://images.amazon.com/images/P/0395186498.0...
# 246005  http://images.amazon.com/images/P/0404077749.0...
#
#                                               Image-URL-M  \
# 259793  http://images.amazon.com/images/P/0312254210.0...
# 119259  http://images.amazon.com/images/P/0061009571.0...
# 198312  http://images.amazon.com/images/P/0866254064.0...
# 115808  http://images.amazon.com/images/P/0395186498.0...
# 246005  http://images.amazon.com/images/P/0404077749.0...
#
#                                               Image-URL-L
# 259793  http://images.amazon.com/images/P/0312254210.0...
# 119259  http://images.amazon.com/images/P/0061009571.0...
# 198312  http://images.amazon.com/images/P/0866254064.0...
# 115808  http://images.amazon.com/images/P/0395186498.0...
# 246005  http://images.amazon.com/images/P/0404077749.0...

# %%
print(books['Year-Of-Publication'].unique())
# Out:
# ['2002' '2001' '1991' '1999' '2000' '1993' '1996' '1988' '2004' '1998'
#  '1994' '2003' '1997' '1983' '1979' '1995' '1982' '1985' '1992' '1986'
#  '1978' '1980' '1952' '1987' '1990' '1981' '1989' '1984' '0' '1968' '1961'
#  '1958' '1974' '1976' '1971' '1977' '1975' '1965' '1941' '1970' '1962'
#  '1973' '1972' '1960' '1966' '1920' '1956' '1959' '1953' '1951' '1942'
#  '1963' '1964' '1969' '1954' '1950' '1967' '2005' '1957' '1940' '1937'
#  '1955' '1946' '1936' '1930' '2011' '1925' '1948' '1943' '1947' '1945'
#  '1923' '2020' '1939' '1926' '1938' '2030' '1911' '1904' '1949' '1932'
#  '1928' '1929' '1927' '1931' '1914' '2050' '1934' '1910' '1933' '1902'
#  '1924' '1921' '1900' '2038' '2026' '1944' '1917' '1901' '2010' '1908'
#  '1906' '1935' '1806' '2021' '2012' '2006' 'DK Publishing Inc' 'Gallimard'
#  '1909' '2008' '1378' '1919' '1922' '1897' '2024' '1376' '2037']

# %%
books['Year-Of-Publication'].isnull().sum()
# Out:
# 0

# %%
books[pd.to_numeric(books['Year-Of-Publication'], errors='coerce').isnull()]
# Out:
#               ISBN                                         Book-Title  \
# 209538  078946697X  DK Readers: Creating the X-Men, How It All Beg...
# 220731  2070426769  Peuple du ciel, suivi de 'Les Bergers\";Jean-M...
# 221678  0789466953  DK Readers: Creating the X-Men, How Comic Book...
#
#        Book-Author Year-Of-Publication  \
# 209538        2000   DK Publishing Inc
# 220731        2003           Gallimard
# 221678        2000   DK Publishing Inc
#
#                                                 Publisher  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-S  \
# 209538  http://images.amazon.com/images/P/078946697X.0...
# 220731  http://images.amazon.com/images/P/2070426769.0...
# 221678  http://images.amazon.com/images/P/0789466953.0...
#
#                                               Image-URL-M Image-URL-L
# 209538  http://images.amazon.com/images/P/078946697X.0...         NaN
# 220731  http://images.amazon.com/images/P/2070426769.0...         NaN
# 221678  http://images.amazon.com/images/P/0789466953.0...         NaN

# %%
books['Year-Of-Publication'] = pd.to_numeric(books['Year-Of-Publication'], errors='coerce')

# %%
print(books['Year-Of-Publication'].isnull().sum())
# Out:
# 3

# %%
books['Year-Of-Publication'] = books['Year-Of-Publication'].fillna(0)

# %%
books[books['Year-Of-Publication'] == 0]['Year-Of-Publication'].count()
# Out:
# 4621

# %%
print(books['Year-Of-Publication'].isnull().sum())
# Out:
# 0

# %%
books.sample(5)
# Out:
#               ISBN                Book-Title            Book-Author  \
# 5840    0553277723       NIGHT SHE DIED, THE        DOROTHY SIMPSON
# 79870   3492225535               Celibidache           Klaus Umbach
# 108981  0670840084               More Please        Barry Humphries
# 173545  0553296655  Prayers to Broken Stones            Dan Simmons
# 100631  207042121X                   Balbala  Abdourahman A. Waberi
#
#         Year-Of-Publication          Publisher  \
# 5840                 1985.0          Crimeline
# 79870                1998.0  Piper Verlag GmbH
# 108981               1992.0             Viking
# 173545               1992.0             Bantam
# 100631               2002.0          Gallimard
#
#                                               Image-URL-S  \
# 5840    http://images.amazon.com/images/P/0553277723.0...
# 79870   http://images.amazon.com/images/P/3492225535.0...
# 108981  http://images.amazon.com/images/P/0670840084.0...
# 173545  http://images.amazon.com/images/P/0553296655.0...
# 100631  http://images.amazon.com/images/P/207042121X.0...
#
#                                               Image-URL-M  \
# 5840    http://images.amazon.com/images/P/0553277723.0...
# 79870   http://images.amazon.com/images/P/3492225535.0...
# 108981  http://images.amazon.com/images/P/0670840084.0...
# 173545  http://images.amazon.com/images/P/0553296655.0...
# 100631  http://images.amazon.com/images/P/207042121X.0...
#
#                                               Image-URL-L
# 5840    http://images.amazon.com/images/P/0553277723.0...
# 79870   http://images.amazon.com/images/P/3492225535.0...
# 108981  http://images.amazon.com/images/P/0670840084.0...
# 173545  http://images.amazon.com/images/P/0553296655.0...
# 100631  http://images.amazon.com/images/P/207042121X.0...

# %%
books['Year-Of-Publication'].dtype
# Out:
# dtype('float64')

# %%
books['Year-Of-Publication'] = books['Year-Of-Publication'].dropna().astype(int)

# %%
books['Year-Of-Publication'].dtype
# Out:
# dtype('int32')

# %%
books.sample(5)
# Out:
#               ISBN                                         Book-Title  \
# 162713  0451182766                                        Double Dead
# 150707  0785280707               The Legend of Storey County: A Novel
# 20528   042518885X  The Wicked Flea: A Dog Lover's Mystery (Dog Lo...
# 54084   0451145747      Of Quests and Kings (Castaways in Time, No 3)
# 182430  1857994353                              A Breath of Fresh Air
#
#           Book-Author  Year-Of-Publication                 Publisher  \
# 162713  Gary Hardwick                 1998                Onyx Books
# 150707   Brock Thoene                 1995         Thomas Nelson Inc
# 20528    Susan Conant                 2003       Berkely Prime Crime
# 54084    Robert Adams                 1986          New Amer Library
# 182430    Erica James                 1996  Phoenix mass market p/bk
#
#                                               Image-URL-S  \
# 162713  http://images.amazon.com/images/P/0451182766.0...
# 150707  http://images.amazon.com/images/P/0785280707.0...
# 20528   http://images.amazon.com/images/P/042518885X.0...
# 54084   http://images.amazon.com/images/P/0451145747.0...
# 182430  http://images.amazon.com/images/P/1857994353.0...
#
#                                               Image-URL-M  \
# 162713  http://images.amazon.com/images/P/0451182766.0...
# 150707  http://images.amazon.com/images/P/0785280707.0...
# 20528   http://images.amazon.com/images/P/042518885X.0...
# 54084   http://images.amazon.com/images/P/0451145747.0...
# 182430  http://images.amazon.com/images/P/1857994353.0...
#
#                                               Image-URL-L
# 162713  http://images.amazon.com/images/P/0451182766.0...
# 150707  http://images.amazon.com/images/P/0785280707.0...
# 20528   http://images.amazon.com/images/P/042518885X.0...
# 54084   http://images.amazon.com/images/P/0451145747.0...
# 182430  http://images.amazon.com/images/P/1857994353.0...

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher', 'Image-URL-M']]

# %%
books.sample(5)
# Out:
#               ISBN                                         Book-Title  \
# 8188    0679892206         Secret Ingredient (Stepping Stone,  paper)
# 261669  0446670286  The Entertainment Weekly Guide to the Greatest...
# 113090  0060006293                                    Home to Harmony
# 242208  1567181635  Falcon Feather &amp; Valkyrie Sword: Feminine ...
# 53700   0843951249                                            Danelaw
#
#                  Book-Author  Year-Of-Publication  \
# 8188           G. E. Stanley                 1999
# 261669  Entertainment Weekly                 1994
# 113090         Philip Gulley                 2002
# 242208          D. J. Conway                 1995
# 53700          Susan Squires                 2003
#
#                             Publisher  \
# 8188               Random House Trade
# 261669                   Warner Books
# 113090            Harper SanFrancisco
# 242208                Llewellyn Pubns
# 53700   Dorchester Publishing Company
#
#                                               Image-URL-M
# 8188    http://images.amazon.com/images/P/0679892206.0...
# 261669  http://images.amazon.com/images/P/0446670286.0...
# 113090  http://images.amazon.com/images/P/0060006293.0...
# 242208  http://images.amazon.com/images/P/1567181635.0...
# 53700   http://images.amazon.com/images/P/0843951249.0...

# %%
books = books.rename(columns={
    'Book-Title': 'title',
    'Book-Author': 'author',
    'Year-Of-Publication': 'year',
    'Publisher': 'publisher',
    'Image-URL-M': 'image-url'
})

# %%
books.sample(5)
# Out:
#               ISBN                                        title  \
# 249031  8516023508                        A Colina Dos Suspiros
# 9826    0673522946                            Technical Writing
# 91331   0809281090                         Winning Bodybuilding
# 65988   1551664216  Second Thoughts (Jackie Kaminsky Mysteries)
# 166948  2266023128                                L Enfant Noir
#
#                  author  year              publisher  \
# 249031    Moacyr Scliar     0   Luso Brazilian Books
# 9826     John M. Lannon  1993  Addison-Wesley Pub Co
# 91331   Franco. Columbu  1977            McGraw-Hill
# 65988     Margot Dalton  1998                   Mira
# 166948      Camara Laye  2001        Distribooks Inc
#
#                                                 image-url
# 249031  http://images.amazon.com/images/P/8516023508.0...
# 9826    http://images.amazon.com/images/P/0673522946.0...
# 91331   http://images.amazon.com/images/P/0809281090.0...
# 65988   http://images.amazon.com/images/P/1551664216.0...
# 166948  http://images.amazon.com/images/P/2266023128.0...

# %%
users = pd.read_csv('data/Users.csv')
ratings = pd.read_csv('data/Ratings.csv')

# %%
users.sample(5)
# Out:
#         User-ID                             Location   Age
# 36493     36494           hawthorne, california, usa   NaN
# 238206   238207           ft. irwin, california, usa   NaN
# 48525     48526           shelbyville, kentucky, usa  22.0
# 154689   154690  edinburgh, scotland, united kingdom  27.0
# 202799   202800           centreville, virginia, usa  32.0

# %%
ratings.sample(5)
# Out:
#          User-ID        ISBN  Book-Rating
# 398790     95923  0446672211            0
# 783139    189623  0349101779            0
# 111217     25757  3499131706            0
# 1056281   252222  0754804461            8
# 1071055   255979  3596152356            0

# %%
print(f"Shape of books: {books.shape}")
print(f"Shape of users: {users.shape}")
print(f"Shape of ratings: {ratings.shape}")
# Out:
# Shape of books: (271360, 6)
# Shape of users: (278858, 3)
# Shape of ratings: (1149780, 3)

# %%
users = users.rename(columns={
    'User-ID': 'user-id',
    'Location': 'location',
    'Age': 'age'
})
ratings = ratings.rename(columns={
    'User-ID': 'user-id',
    'Book-Rating': 'rating'
})

# %%
len(ratings['user-id'].unique())
# Out:
# 105283

# %%
x = ratings['user-id'].value_counts() > 200
x[x]
# Out:
# user-id
# 11676     True
# 198711    True
# 153662    True
# 98391     True
# 35859     True
#           ...
# 274808    True
# 28634     True
# 59727     True
# 268622    True
# 188951    True
# Name: count, Length: 899, dtype: bool

# %%
ratings = ratings[ratings['user-id'].isin(x[x].index)]

# %%
ratings.shape
# Out:
# (526356, 3)

# %%
len(ratings['user-id'].unique())
# Out:
# 899

# %%
ratings.sample(5)
# Out:
#          user-id        ISBN  rating
# 577231    138844  0449219461       0
# 1024851   245827  0307155498       0
# 295303     69971  0345418611       0
# 365682     87746  0679405283       0
# 298254     70594  0553801945       8

# %%
ratings_with_books = ratings.merge(books, on='ISBN')

# %%
ratings_with_books.shape
# Out:
# (487671, 8)

# %%
ratings_with_books.sample(5)
# Out:
#         user-id        ISBN  rating  \
# 180529   102967  0449219550       0
# 468725   264321  0345384377       0
# 323122   187517  0399148019       8
# 289321   170229  039457060X       0
# 141439    81492  0446356956       0
#
#                                                     title            author  \
# 180529                                           Longshot      Dick Francis
# 468725                                      Sole Survivor       DEAN KOONTZ
# 323122                              The Absence of Nectar  Kathy Hepinstall
# 289321  Reasonable Creatures: Essays on Women and Femi...     Katha Pollitt
# 141439                                        The Fortune     Michael Korda
#
#         year            publisher  \
# 180529  1994        Fawcett Books
# 468725  1997     Ballantine Books
# 323122  2001  G. P. Putnam's Sons
# 289321  1994      Alfred A. Knopf
# 141439  1990         Warner Books
#
#                                                 image-url
# 180529  http://images.amazon.com/images/P/0449219550.0...
# 468725  http://images.amazon.com/images/P/0345384377.0...
# 323122  http://images.amazon.com/images/P/0399148019.0...
# 289321  http://images.amazon.com/images/P/039457060X.0...
# 141439  http://images.amazon.com/images/P/0446356956.0...

# %%
num_ratings = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
num_ratings.sample(5)
# Out:
#                                                     title  rating
# 64938                 Keeping Fit (Let Me Read : Level 1)       1
# 94832                        Puppy Love (Beethoven's 2nd)       4
# 150369                                     Unsafe Keeping       1
# 109391  Star Trek: Phase II : The Making of the Lost S...       2
# 135532                    The Rancher's Hand-Picked Bride       5

# %%
num_ratings = num_ratings.rename(columns={
    'rating': 'num-of-ratings'
})

# %%
num_ratings.sample(5)
# Out:
#                                                     title  num-of-ratings
# 8762    American Exorcism: Expelling Demons in the Lan...               1
# 15353                               Best of Helpful Hints               1
# 110016  Still Lickin' the Spoon (And Other Confessions...               1
# 30820                            David Hockney's Dog Days               1
# 124110                                The Final Deduction               4

# %%
final_ratings = ratings_with_books.merge(num_ratings, on='title')

# %%
final_ratings.sample(5)
# Out:
#         user-id        ISBN  rating  \
# 393938   227447  1551668920       0
# 433020   242824  0553441531       0
# 53775     29259  0345307674       0
# 473399   266226  0425193918       0
# 413186   234828  0671879472       8
#
#                                                     title             author  \
# 393938                               A Season Of Miracles     Heather Graham
# 433020               A Moment in Time (Loveswept, No 489)  Helen Mittermeyer
# 53775                      Return of the Jedi (Star Wars)         James Kahn
# 473399                   Mrs. Jeffries Sweeps the Chimney   Emily Brightwell
# 413186  The SECRET SANTA (NANCY DREW NOTEBOOK 3) : THE...      Carolyn Keene
#
#         year                 publisher  \
# 393938  2002                      Mira
# 433020  1991                 Loveswept
# 53775   1983             Del Rey Books
# 473399  2004  Berkley Publishing Group
# 413186  1994                   Aladdin
#
#                                                 image-url  num-of-ratings
# 393938  http://images.amazon.com/images/P/1551668920.0...              15
# 433020  http://images.amazon.com/images/P/0553441531.0...               3
# 53775   http://images.amazon.com/images/P/0345307674.0...              21
# 473399  http://images.amazon.com/images/P/0425193918.0...               3
# 413186  http://images.amazon.com/images/P/0671879472.0...               1

# %%
final_ratings.shape
# Out:
# (487671, 9)

# %%
final_ratings = final_ratings[final_ratings['num-of-ratings'] >= 50]

# %%
final_ratings.sample(5)
# Out:
#         user-id        ISBN  rating  \
# 158188    93047  0805063897       0
# 224254   129358  0345313860       0
# 473145   266226  0312983867       0
# 273205   158295  0671741195       0
# 461002   258185  0449221490       0
#
#                                                     title              author  \
# 158188   Nickel and Dimed: On (Not) Getting By in America  Barbara Ehrenreich
# 224254   The Vampire Lestat (Vampire Chronicles, Book II)           ANNE RICE
# 473145  Hard Eight : A Stephanie Plum Novel (A Stephan...     Janet Evanovich
# 273205                               The Cradle Will Fall  Mary Higgins Clark
# 461002                                   L Is for Lawless         Sue Grafton
#
#         year                publisher  \
# 158188  2002                Owl Books
# 224254  1986         Ballantine Books
# 473145  2003  St. Martin's Paperbacks
# 273205  1991                   Pocket
# 461002  1996            Fawcett Books
#
#                                                 image-url  num-of-ratings
# 158188  http://images.amazon.com/images/P/0805063897.0...             112
# 224254  http://images.amazon.com/images/P/0345313860.0...             123
# 473145  http://images.amazon.com/images/P/0312983867.0...             112
# 273205  http://images.amazon.com/images/P/0671741195.0...              58
# 461002  http://images.amazon.com/images/P/0449221490.0...              70

# %%
final_ratings.shape
# Out:
# (61853, 9)

# %%
final_ratings = final_ratings.drop_duplicates(['title', 'user-id'])

# %%
final_ratings.shape
# Out:
# (59850, 9)

# %%
book_pivot = final_ratings.pivot_table(columns='user-id', index='title', values='rating')

# %%
book_pivot
# Out:
# user-id                                             254     2276    2766    \
# title
# 1984                                                   9.0     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN    10.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user-id                                             2977    3363    3757    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user-id                                             4017    4385    6242    \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     7.0
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user-id                                             6251    ...  274004  \
# title                                                       ...
# 1984                                                   NaN  ...     NaN
# 1st to Die: A Novel                                    NaN  ...     NaN
# 2nd Chance                                             NaN  ...     NaN
# 4 Blondes                                              0.0  ...     NaN
# 84 Charing Cross Road                                  NaN  ...     NaN
# ...                                                    ...  ...     ...
# Year of Wonders                                        NaN  ...     NaN
# You Belong To Me                                       NaN  ...     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     NaN
# Zoya                                                   NaN  ...     NaN
# \O\" Is for Outlaw"                                    NaN  ...     NaN
#
# user-id                                             274061  274301  274308  \
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     0.0
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     8.0     NaN
#
# user-id                                             274808  275970  277427  \
# title
# 1984                                                   NaN     0.0     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN    10.0     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     0.0     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     0.0     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# user-id                                             277478  277639  278418
# title
# 1984                                                   NaN     NaN     NaN
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2nd Chance                                             NaN     0.0     NaN
# 4 Blondes                                              NaN     NaN     NaN
# 84 Charing Cross Road                                  NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# [742 rows x 888 columns]

# %%
book_pivot = book_pivot.fillna(0)

# %%
book_pivot
# Out:
# user-id                                             254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user-id                                             2977    3363    3757    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        7.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user-id                                             4017    4385    6242    \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     7.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user-id                                             6251    ...  274004  \
# title                                                       ...
# 1984                                                   0.0  ...     0.0
# 1st to Die: A Novel                                    0.0  ...     0.0
# 2nd Chance                                             0.0  ...     0.0
# 4 Blondes                                              0.0  ...     0.0
# 84 Charing Cross Road                                  0.0  ...     0.0
# ...                                                    ...  ...     ...
# Year of Wonders                                        0.0  ...     0.0
# You Belong To Me                                       0.0  ...     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0  ...     0.0
# Zoya                                                   0.0  ...     0.0
# \O\" Is for Outlaw"                                    0.0  ...     0.0
#
# user-id                                             274061  274301  274308  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     8.0     0.0
#
# user-id                                             274808  275970  277427  \
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0    10.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# user-id                                             277478  277639  278418
# title
# 1984                                                   0.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# 84 Charing Cross Road                                  0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# [742 rows x 888 columns]

# %% [markdown]
# ### Sparse Matrix Creation
# Since the dataset can be sparse (many users haven't rated many books), we convert the pivot table into a sparse matrix format to optimize memory usage.

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
book_sparse
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 14961 stored elements and shape (742, 888)>

# %% [markdown]
# ### K-Nearest Neighbors Model Training
# We will use the KNN algorithm to train our model. The KNN model identifies similar books based on the ratings users have given.

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1, -1), n_neighbors=6)

# %%
distance
# Out:
# array([[ 0.        , 67.75691847, 68.05145112, 72.277244  , 75.81556568,
#         76.30203143]])

# %%
suggestion
# Out:
# array([[237, 238, 240, 241, 184, 536]], dtype=int64)

# %%
for book in suggestion[0]:
    print(book_pivot.index[book])
# Out:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Exclusive
# The Cradle Will Fall

# %%
book_pivot.index[237]
# Out:
# 'Harry Potter and the Chamber of Secrets (Book 2)'

# %%
book_name = book_pivot.index

# %%
book_name
# Out:
# Index(['1984', '1st to Die: A Novel', '2nd Chance', '4 Blondes',
#        '84 Charing Cross Road', 'A Bend in the Road', 'A Case of Need',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Civil Action', 'A Cry In The Night',
#        ...
#        'Winter Solstice', 'Wish You Well', 'Without Remorse',
#        'Wizard and Glass (The Dark Tower, Book 4)', 'Wuthering Heights',
#        'Year of Wonders', 'You Belong To Me',
#        'Zen and the Art of Motorcycle Maintenance: An Inquiry into Values',
#        'Zoya', '\O\" Is for Outlaw"'],
#       dtype='object', name='title', length=742)

# %% [markdown]
# ### Saving Model Artifacts
# Once the model is trained, we save the trained model and other important data (like the book pivot table) using `pickle`, so they can be used later without retraining the model.

# %%
import pickle
pickle.dump(model, open('artifacts/model.pkl', 'wb'))
pickle.dump(book_name, open('artifacts/book_name.pkl', 'wb'))
pickle.dump(final_ratings, open('artifacts/final_ratings.pkl', 'wb'))
pickle.dump(book_pivot, open('artifacts/book_pivot.pkl', 'wb'))

# %% [markdown]
# ### Book Recommendation Function
# Finally, we define a function that takes a book name as input and returns a list of recommended books based on the KNN model.

# %%
def recommend_book(book_name, n_neighbors=6):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1, -1), n_neighbors=n_neighbors+1)
    for book in suggestion[0]:
        print(book_pivot.index[book])
    

recommended_books = recommend_book(book_name='Harry Potter and the Chamber of Secrets (Book 2)', n_neighbors=10)
# Out:
# Harry Potter and the Chamber of Secrets (Book 2)
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Sorcerer's Stone (Book 1)
# Exclusive
# The Cradle Will Fall
# Jacob Have I Loved
# Tom Clancy's Op-Center (Tom Clancy's Op Center (Paperback))
# The Witness
# Toxin
# Truly, Madly Manhattan
